# %%
# !pip install dataprep
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 15.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 28.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.6/133.6 kB 7.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 22.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 39.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 24.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 22.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 23.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 764.0/764.0 kB 15.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 46.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 3.6 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from dataprep.eda import create_report

# %%
file_path = '/content/drive/MyDrive/HTF4_final/data/Retail_sale.xlsx'  # Đường dẫn đến file Excel của bạn
sheet1 = pd.read_excel(file_path, sheet_name='10.SE Regional Sales')
sheet2 = pd.read_excel(file_path, sheet_name='11.SE Regional Sales')
sheet3 = pd.read_excel(file_path, sheet_name='12.SE Regional Sales')
customer = pd.read_excel(file_path, sheet_name='Customer')
sale = pd.read_excel(file_path, sheet_name='Sale')
sale
# Out:
#       Order ID  Customer Last Name Customer First Name  Customer ID  \
# 0          1001             Hughes               Lewis         1234
# 1          1002              Gomez                 Ali         1235
# 2          1003               Beck                Mila         1236
# 3          1004             Juarez             Ryleigh         1237
# 4          1005            Preston            Leonidas         1238
# ...         ...                ...                 ...          ...
# 2995       3996            Robbins                Crew         2227
# 2996       3997            Salinas              Willow         2228
# 2997       3998               Bond             Malachi         2229
# 2998       3999             Willis             Patrick         2230
# 2999       4000            Compton              Dallas         2231
#
#        Product Category Order Date  Quantity Ordered Order Status State  \
# 0              Clothing 2022-10-11                16    Delivered    LA
# ...

# %%
saleReport = create_report(sale)
sheet1Report = create_report(sheet1)
sheet2Report = create_report(sheet2)
sheet3Report = create_report(sheet3)
customerReport = create_report(customer)
# Out:
# Computing series-max-agg-e3cb6124d4f307fa3e124c689ada5b3f:   0%|          | 0/1831 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# Computing loc-series-sum-chunk-series-sum-agg-14aadc5bfe82be352dc60e240c99f9b9:  46%|████▌     | 839/1831 [00:00<00:00, 1274.84it/s]/usr/local/lib/python3.10/dist-packages/scipy/stats/_stats_py.py:1606: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_stats_py.py:1606: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   b2 = skew(a, axis)
# ...

# %%
sheet1Report
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
sheet2Report
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
sheet3Report
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
saleReport
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
customerReport
# Out:
# Output hidden; open in https://colab.research.google.com to view.
